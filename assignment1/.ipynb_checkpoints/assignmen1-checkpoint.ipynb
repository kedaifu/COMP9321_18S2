# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Merge the two datasets Olympics_dataset1.csv and Olympics_dataset2.csv 
# and display the first five rows (do not concatenate the datasets). 

# question1

def question_1(file_1='Olympics_dataset1.csv', file_2='Olympics_dataset2.csv'):
    df_winter = pd.read_csv(file_2, skiprows=1)
    df_summer = pd.read_csv(file_1, skiprows=1)
    df_winter.rename(columns={'Unnamed: 0':'Country'}, inplace=True)
    df_summer.rename(columns={'Unnamed: 0':'Country'}, inplace=True)
    result1 = pd.merge(df_summer, df_winter, how='left', left_on='Country', right_on='Country')
    result1 = result1.rename(index=str, columns={"Number of Games the country participated in_x": "Number of Games the country participated in summer"})
    result1 = result1.rename(index=str, columns={"Gold_x":"Gold_summer","Silver_x":"Silver_summer","Bronze_x":"Bronze_summer"})
    result1 = result1.rename(index=str, columns={"Number of Games the country participated in_y": "Number of Games the country participated in winter"})
    result1 = result1.rename(index=str, columns={"Gold_y":"Gold_winter","Silver_y":"Silver_winter","Bronze_y":"Bronze_winter"})
    result1 = result1.rename(index=str, columns={"Total_x":"Total_summer", "Total_y":"Total_winter","Total.1":"Total"})
    result1 = result1.rename(index=str, columns={"Gold.1":"Gold_total", "Silver.1":"Silver_total","Bronze.1":"Bronze_total"})
    result1 = result1.rename(index=str, columns={"Number of Games the country participated in.1": "Number of Games the country participated in total"})
    return result1

df = question_1()

# %%
# question2

# Set the index as the country name and then display the first country in the Dataframe. 

# Q1: abbreviation?

def question_2():
    result2 = question_1()
    result2 = result2.set_index('Country')
     
    result2 = result2.head(1)
    return result2

q2 = question_2()
q2
# Out:
#                    Rubish  Number of Games the country participated in summer  \
# Country
#  Afghanistan (AFG)    BLA                                               14.0
#
#                    Gold_summer Silver_summer Bronze_summer Total_summer  \
# Country
#  Afghanistan (AFG)           0             0             2            2
#
#                     Number of Games the country participated in winter  \
# Country
#  Afghanistan (AFG)                                                0.0
#
#                    Gold_winter Silver_winter Bronze_winter Total_winter  \
# Country
#  Afghanistan (AFG)           0             0             0            0
#
#                     Number of Games the country participated in total  \
# Country
#  Afghanistan (AFG)                                               14.0
#
#                    Gold_total Silver_total Bronze_total Total
# Country
#  Afghanistan (AFG)          0            0            2     2

# %%
# question3


# Remove the rubish column and display the first five rows.

def question_3():
    result3 = question_1()
    result3 = result3.drop('Rubish', axis=1)
    result3 = result3.head(5)
    return result3

q3 = question_3()
q3
# Out:
#                     Country  \
# 0         Afghanistan (AFG)
# 1             Algeria (ALG)
# 2           Argentina (ARG)
# 3             Armenia (ARM)
# 4   Australasia (ANZ) [ANZ]
#
#    Number of Games the country participated in summer Gold_summer  \
# 0                                               14.0            0
# 1                                               13.0            5
# 2                                               24.0           21
# 3                                                6.0            2
# 4                                                2.0            3
#
#   Silver_summer Bronze_summer Total_summer  \
# 0             0             2            2
# 1             4             8           17
# 2            25            28           74
# 3             6             6           14
# 4             4             5           12
#
#    Number of Games the country participated in winter Gold_winter  \
# 0                                                0.0            0
# 1                                                3.0            0
# 2                                               19.0            0
# 3                                                7.0            0
# 4                                                0.0            0
#
#   Silver_winter Bronze_winter Total_winter  \
# 0             0             0            0
# 1             0             0            0
# 2             0             0            0
# 3             0             0            0
# 4             0             0            0
#
#    Number of Games the country participated in total Gold_total Silver_total  \
# 0                                               14.0          0            0
# 1                                               16.0          5            4
# 2                                               43.0         21           25
# 3                                               13.0          2            6
# 4                                                2.0          3            4
#
#   Bronze_total Total
# 0            2     2
# 1            8    17
# 2           28    74
# 3            6    14
# 4            5    12

# %%
# question4

# Q1: do we need to re-index the every row?

# Remove the rows with NaN fields and display the last ten rows.

def question_4():
    result4 = question_1()
    result4 = result4.dropna()
    result4 = result4.tail(10)
    return result4

q4 = question_4()
q4
# Out:
#                                            Country Rubish  \
# 148                           Virgin Islands (ISV)    BLA
# 149                         Yugoslavia (YUG) [YUG]    BLA
# 150                             Zambia (ZAM) [ZAM]    BLA
# 152                           Zimbabwe (ZIM) [ZIM]    BLA
# 153                       Unified Team (EUN) [EUN]    BLA
# 154       Independent Olympic Athletes (IOA) [IOA]    BLA
# 155   Independent Olympic Participants (IOP) [IOP]    BLA
# 156       Olympic Athletes from Russia (OAR) [OAR]    BLA
# 157                         Mixed team (ZZX) [ZZX]    BLA
# 158                                         Totals    BLA
#
#      Number of Games the country participated in summer Gold_summer  \
# 148                                               12.0            0
# 149                                               18.0           28
# 150                                               13.0            0
# 152                                               13.0            3
# 153                                                1.0           45
# 154                                                3.0            1
# 155                                                1.0            0
# 156                                                0.0            0
# 157                                                3.0            8
# 158                                               28.0        5,115
#
#     Silver_summer Bronze_summer Total_summer  \
# 148             1             0            1
# 149            31            31           90
# 150             1             1            2
# 152             4             1            8
# 153            38            29          112
# 154             0             1            2
# 155             1             2            3
# 156             0             0            0
# 157             5             4           17
# 158         5,080         5,482       15,677
#
#      Number of Games the country participated in winter Gold_winter  \
# 148                                                7.0            0
# 149                                               16.0            0
# 150                                                0.0            0
# 152                                                1.0            0
# 153                                                1.0            9
# 154                                                0.0            0
# 155                                                0.0            0
# 156                                                1.0            2
# 157                                                0.0            0
# 158                                               23.0        1,060
#
#     Silver_winter Bronze_winter Total_winter  \
# 148             0             0            0
# 149             3             1            4
# 150             0             0            0
# 152             0             0            0
# 153             6             8           23
# 154             0             0            0
# 155             0             0            0
# 156             6             9           17
# 157             0             0            0
# 158         1,058         1,050        3,168
#
#      Number of Games the country participated in total Gold_total  \
# 148                                               19.0          0
# 149                                               34.0         28
# 150                                               13.0          0
# 152                                               14.0          3
# 153                                                2.0         54
# 154                                                3.0          1
# 155                                                1.0          0
# 156                                                1.0          2
# 157                                                3.0          8
# 158                                               51.0      6,175
#
#     Silver_total Bronze_total   Total
# 148            1            0       1
# 149           34           32      94
# 150            1            1       2
# 152            4            1       8
# 153           44           37     135
# 154            0            1       2
# 155            1            2       3
# 156            6            9      17
# 157            5            4      17
# 158        6,138        6,532  18,845

# %%
# question5

# Calculate and display which country has won the most gold medals in summer games? 

def question_5():
    result5 = question_1()
    result5 = result5.dropna(subset=['Gold_summer'])
    result5['Gold_summer'] = result5['Gold_summer'].apply(lambda x: x.replace(',',''))
    result5['Gold_summer'] = result5['Gold_summer'].astype('float')
    result5 = result5.sort_values(by=['Gold_summer'])
    
    result5 = result5.iloc[[-2]]
    return result5
q5 = question_5()
q5
# Out:
#                                   Country Rubish  \
# 143   United States (USA) [P] [Q] [R] [Z]    BLA
#
#      Number of Games the country participated in summer  Gold_summer  \
# 143                                               27.0        1022.0
#
#     Silver_summer Bronze_summer Total_summer  \
# 143           795           705        2,522
#
#      Number of Games the country participated in winter Gold_winter  \
# 143                                               23.0          105
#
#     Silver_winter Bronze_winter Total_winter  \
# 143           110            90          305
#
#      Number of Games the country participated in total Gold_total  \
# 143                                               50.0      1,127
#
#     Silver_total Bronze_total  Total
# 143          905          795  2,827

# %%
# question6

# Calculate and display which country 
# had the biggest difference between their summer and winter gold medal? 

def question_6():
    
    result6 = question_1()
    result6 = result6.dropna(subset=['Gold_summer'])
     
    result6['Gold_summer'] = result6['Gold_summer'].apply(lambda x: x.replace(',',''))
    result6['Gold_summer'] = result6['Gold_summer'].astype('float')
    
    result6['Gold_winter'] = result6['Gold_winter'].apply(lambda x: x.replace(',',''))
    result6['Gold_winter'] = result6['Gold_winter'].astype('float')

    newSeries = abs(result6['Gold_summer'] - result6['Gold_winter'])
    newSeries
    result6['Diff'] = pd.Series(newSeries, index=result6.index)
    result6 = result6.sort_values(by=['Diff'])
    result6 = result6.iloc[[-2]]
    return result6

q6 = question_6()
q6
# Out:
#                                   Country Rubish  \
# 143   United States (USA) [P] [Q] [R] [Z]    BLA
#
#      Number of Games the country participated in summer  Gold_summer  \
# 143                                               27.0        1022.0
#
#     Silver_summer Bronze_summer Total_summer  \
# 143           795           705        2,522
#
#      Number of Games the country participated in winter  Gold_winter  \
# 143                                               23.0         105.0
#
#     Silver_winter Bronze_winter Total_winter  \
# 143           110            90          305
#
#      Number of Games the country participated in total Gold_total  \
# 143                                               50.0      1,127
#
#     Silver_total Bronze_total  Total   Diff
# 143          905          795  2,827  917.0

# %%
# question7

# Q3: do we need to sort it by the country name, if they have the same total?
# Q4: do we need to skip the total row?

# Sort the countries in descending order,
# according to the number of total of medals earned throughout the history 
# and display the first and last 5 rows. 

def question_7(): 
    result7 = question_1()
    result7['Total'] = result7['Total'].astype(str)
    result7['Total'] = result7['Total'].apply(lambda x: x.replace(',',''))
    result7['Total'] = result7['Total'].astype('float',errors = 'ignore')
    result7 = result7.sort_values(by=['Total'],ascending=False)
    result7 = pd.concat([result7.head(5), result7.tail(5)]) 
    return result7

q7 = question_7()
q7
# Out:
#                                   Country Rubish  \
# 158                                Totals    BLA
# 143   United States (USA) [P] [Q] [R] [Z]    BLA
# 114              Soviet Union (URS) [URS]    BLA
# 52          Great Britain (GBR) [GBR] [Z]    BLA
# 47                Germany (GER) [GER] [Z]    BLA
# 17                  Treasure Island (TRI)    NaN
# 53                Republic of Mars (MARS)    NaN
# 84             Kingdom of the Rock (ROCK)    NaN
# 105     Kingdom of the Stromlands (STORM)    NaN
# 151             Republic of Gamers (GAME)    BLA
#
#      Number of Games the country participated in summer Gold_summer  \
# 158                                               28.0        5,115
# 143                                               27.0        1,022
# 114                                                9.0          395
# 52                                                28.0          263
# 47                                                16.0          191
# 17                                                 NaN          NaN
# 53                                                 NaN          NaN
# 84                                                 NaN          NaN
# 105                                                NaN          NaN
# 151                                                NaN          NaN
#
#     Silver_summer Bronze_summer Total_summer  \
# 158         5,080         5,482       15,677
# 143           795           705        2,522
# 114           319           296        1,010
# 52            295           291          849
# 47            194           230          615
# 17            NaN           NaN          NaN
# 53            NaN           NaN          NaN
# 84            NaN           NaN          NaN
# 105           NaN           NaN          NaN
# 151           NaN           NaN          NaN
#
#      Number of Games the country participated in winter Gold_winter  \
# 158                                               23.0        1,060
# 143                                               23.0          105
# 114                                                9.0           78
# 52                                                23.0           11
# 47                                                12.0           92
# 17                                                 NaN          NaN
# 53                                                 NaN          NaN
# 84                                                 NaN          NaN
# 105                                                NaN          NaN
# 151                                                NaN          NaN
#
#     Silver_winter Bronze_winter Total_winter  \
# 158         1,058         1,050        3,168
# 143           110            90          305
# 114            57            59          194
# 52              4            16           31
# 47             88            60          240
# 17            NaN           NaN          NaN
# 53            NaN           NaN          NaN
# 84            NaN           NaN          NaN
# 105           NaN           NaN          NaN
# 151           NaN           NaN          NaN
#
#      Number of Games the country participated in total Gold_total  \
# 158                                               51.0      6,175
# 143                                               50.0      1,127
# 114                                               18.0        473
# 52                                                51.0        274
# 47                                                28.0        283
# 17                                                 NaN        NaN
# 53                                                 NaN        NaN
# 84                                                 NaN        NaN
# 105                                                NaN        NaN
# 151                                                NaN        NaN
#
#     Silver_total Bronze_total    Total
# 158        6,138        6,532  18845.0
# 143          905          795   2827.0
# 114          376          355   1204.0
# 52           299          307    880.0
# 47           282          290    855.0
# 17           NaN          NaN      NaN
# 53           NaN          NaN      NaN
# 84           NaN          NaN      NaN
# 105          NaN          NaN      NaN
# 151          NaN          NaN      NaN

# %%
# question8
# Plot a bar chart of the top 10 countries 
# (according to the sorting in Question 7). 
# For each country use a stacked bar chart showing for each county the total medals 
# for winter and summer games. 
# See example chart below

def question_8(): 
    
    result8 = question_1()
    
    result8 = result8.dropna()
    
    result8['Total_summer'] = result8['Total_summer'].apply(lambda x: x.replace(',',''))
    result8['Total_summer'] = result8['Total_summer'].astype('float')
    
    result8['Total_winter'] = result8['Total_winter'].apply(lambda x: x.replace(',',''))
    result8['Total_winter'] = result8['Total_winter'].astype('float')
    
    result8['Total'] = result8['Total'].apply(lambda x: x.replace(',',''))
    result8['Total'] = result8['Total'].astype('float')
    
    result8 = result8.sort_values(by='Total', ascending=False)
    
    summer = tuple(result8.iloc[1:11,6].tolist())
    winter = tuple(result8.iloc[1:11,11].tolist())
    country = tuple(result8.iloc[1:11,0].tolist())
    
    N = 10
 
    ind = np.arange(N)     
    width = 0.5       
    p1 = plt.barh(ind, summer, width)
    p2 = plt.barh(ind, winter, width,
                 left=summer)
    plt.gca().invert_yaxis()
    plt.title('total medals for winter and summer games')
    plt.yticks(ind, country)
    plt.yticks(np.arange(0, 10, 1))
    plt.legend((p1[0], p2[0]), ('summer', 'winter'))

    plt.show()

question_8()

# %%
# Plot a bar chart of the countries 
# (United States, Australia, Great Britain, Japan, New Zealand). 
# For each county you need to show the gold, 
# silver and bronze medals for winter games. See example below of the chart: 
def question_9(): 
    
    result9 = question_1()
    result9 = result9[result9['Country'].str.contains('United States|Australia|Great Britain|Japan|New Zealand')]
    
    result9['Gold_winter'] = result9['Gold_winter'].apply(lambda x: x.replace(',',''))
    result9['Gold_winter'] = result9['Gold_winter'].astype('float')
    
    result9['Silver_winter'] = result9['Silver_winter'].apply(lambda x: x.replace(',',''))
    result9['Silver_winter'] = result9['Silver_winter'].astype('float')
    
    result9['Bronze_winter'] = result9['Bronze_winter'].apply(lambda x: x.replace(',',''))
    result9['Bronze_winter'] = result9['Bronze_winter'].astype('float')
    
    N = 5
 
    ind = np.arange(N) 
    width = 0.5
    
    p1 = plt.bar(ind*2-width, result9['Gold_winter'], width)
    p2 = plt.bar(ind*2 , result9['Silver_winter'], width)
    p3 = plt.bar(ind*2 + width, result9['Bronze_winter'], width)
    plt.xticks(ind*2, result9['Country'],rotation=90)
    
    plt.yticks(np.arange(0, 100, 10))
    plt.legend((p1[0], p2[0], p3[0]), ('Gold', 'Silver','Bronze'))
    
    plt.show()
    

q9
# Out:
#                                   Country Rubish  \
# 6               Australia (AUS) [AUS] [Z]    BLA
# 52          Great Britain (GBR) [GBR] [Z]    BLA
# 70                            Japan (JPN)    BLA
# 97                New Zealand (NZL) [NZL]    BLA
# 143   United States (USA) [P] [Q] [R] [Z]    BLA
#
#      Number of Games the country participated in summer Gold_summer  \
# 6                                                 26.0          147
# 52                                                28.0          263
# 70                                                22.0          142
# 97                                                23.0           46
# 143                                               27.0        1,022
#
#     Silver_summer Bronze_summer Total_summer  \
# 6             163           187          497
# 52            295           291          849
# 70            135           162          439
# 97             27            44          117
# 143           795           705        2,522
#
#      Number of Games the country participated in winter  Gold_winter  \
# 6                                                 19.0           5.0
# 52                                                23.0          11.0
# 70                                                21.0          14.0
# 97                                                16.0           0.0
# 143                                               23.0         105.0
#
#      Silver_winter  Bronze_winter Total_winter  \
# 6              5.0            5.0           15
# 52             4.0           16.0           31
# 70            22.0           22.0           58
# 97             1.0            2.0            3
# 143          110.0           90.0          305
#
#      Number of Games the country participated in total Gold_total  \
# 6                                                 45.0        152
# 52                                                51.0        274
# 70                                                43.0        156
# 97                                                39.0         46
# 143                                               50.0      1,127
#
#     Silver_total Bronze_total  Total
# 6            168          192    512
# 52           299          307    880
# 70           157          184    497
# 97            28           46    120
# 143          905          795  2,827

# %%
import pandas
import matplotlib.pyplot as plt
import numpy as np

df = pandas.DataFrame(dict(graph=['Item one', 'Item two', 'Item three'],
                           n=[3, 5, 2], m=[6, 1, 3])) 
df
#print(len(df))
#ind = np.arange(len(df))
#width = 0.4

#fig, ax = plt.subplots()
#ax.barh(ind, df.n, width, color='red', label='N')
#ax.barh(ind + width, df.m, width, color='green', label='M')

#ax.set(yticks=ind + width, yticklabels=df.graph, ylim=[2*width - 1, len(df)])
#ax.legend()

#plt.show()
# Out:
#         graph  m  n
# 0    Item one  6  3
# 1    Item two  1  5
# 2  Item three  3  2
